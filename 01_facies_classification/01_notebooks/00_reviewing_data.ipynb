# %%
import pandas as pd

# Replace 'file_path.csv' with the actual path to your CSV file
df = pd.read_csv('C:/Appl/python_libraries/IFP_ML_Miniprojects/01_facies_classification/00_data/02_SEG_2016_ml_contest/facies_vectors.csv')

# Display the dataframe
df

training_data = df

# %%
df['Well Name'].value_counts()
value_counts = df['Well Name'].value_counts()
total_row = pd.Series({'Total': value_counts.sum()})
result = pd.concat([value_counts, total_row])
result
# Out:
# CROSS H CATTLE      501
# SHRIMPLIN           471
# ALEXANDER D         466
# NEWBY               463
# LUKE G U            461
# SHANKLE             449
# KIMZEY A            439
# NOLAN               415
# CHURCHMAN BIBLE     404
# Recruit F9           80
# Total              4149
# dtype: int64

# %%
result.to_csv('output.csv', index=True, header=True)

# %% [markdown]
# Splitting the dataset

# %%
blind = training_data[training_data['Well Name'] == 'SHANKLE']
training_data = training_data[training_data['Well Name'] != 'SHANKLE']

# %%
training_data['Well Name'] = training_data['Well Name'].astype('category')
training_data['Formation'] = training_data['Formation'].astype('category')
training_data['Well Name'].unique()
# Out:
# C:\Users\vesc\AppData\Local\Temp\ipykernel_28652\2491569812.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Well Name'] = training_data['Well Name'].astype('category')
# C:\Users\vesc\AppData\Local\Temp\ipykernel_28652\2491569812.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_data['Formation'] = training_data['Formation'].astype('category')
# ...

# %%
from sklearn import svm

# %% [markdown]
# **Kick-off questions:**
#
# How is the distribution of the data across the wells? <br>
# What implications does this have for machine learning?
#
# How is the distribution of the data across classes? <br>
# What implications does this have when selecting training and validation datasets?
